# %% [markdown]
# # Quiz
# **Submit this notebook as well as its PDF version to the bcourse**
# File names should start with your SID

# %%
import numpy as np
import math as m
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 1
#
# - define a function to calculate the Poisson probability of observing $k$ when $\lambda$ is expected. Recall Poisson probability function is defined as
# ## $f(k,\lambda) = \frac{e^{-\lambda}\lambda^{k}}{k!}$.
# - calculate the Poisson probability in the case where $k = 30$, $\lambda = 25$; in other words, calculate the value of $f(30,25)$.
# - calculate the Poisson probability of observing a $k$ between 30 and 100, given $\lambda = 25$; in other words, calculate the value of $\sum_{k = 30}^{100} f(k,25)$

# %%
#define the function here

# %%
# calculate the probabilities

# %% [markdown]
# # Problem 2
# - Load the text file `news.txt` (which is in the same directory) as this notebook
# - Count the number of lines in this file
# - Find all the lines that contain the word `Berkeley`, replace the string `UC` in these lines by `University of California`, and then print all these lines to a new text file named as `output.txt`. In other words, all those lines that do not contain `Berkeley` should not be present in the output.txt file.
# - in a new cell, use `%cat output.txt` to print out the content of output.txt

# %% [markdown]
# # Problem 3
# - Calculate the correlation between variable x and y using Pearson correlation formula
# - ## $corr(x,y) = \frac{\sum_i(x_i - \mu_{x})(y_i - \mu_{y})}{N\sigma_{x}\sigma_{y}}$,
#     - where $\mu_{x}$ and $\mu_{y}$ are the mean values of ${x_i}$ and ${y_i}$, respectively, and $\sigma_{x}$ and $\sigma_{y}$ are the standard deivations of ${x_i}$ and ${y_i}$, respecitvely. This formula is identical to the one you've seen in the workshop two weeks ago.
# - x and y values are given in the cell below

# %%
# Do not modify this cell
# definition of x and y
np.random.seed(1)
x = np.random.exponential(50,size=500)
y = np.random.normal(x,100,size=500)

# %%
#def correlation function here

def corr(x, y):

# %%
print('Correlation between x and y is %4.2f'% corr(x,y))
# Out:
# Correlation between x and y is 0.46

# %% [markdown]
# # Problem 4
# - calculate the running average of the sequence of x,y
# - running average is given by
#     $<y_i> = \frac{1}{2r+1}\sum_{j=i-r}^{i+r} y_j$
# - use r = 3 for this problem
# - your running average should be given a numpy array of shape (n,) where n is the number of points in the running average sequence. Name your running average as R, so that the visualization cell can properly display the running average.

# %%
# Execution only. Do not modify this cell
# This cell generates data points of (x,y) and visualize it

np.random.seed(1)
x = np.linspace(0,2*np.pi,100)
y = np.sin(x/2) * np.random.normal(1,0.2,size=100)
plt.scatter(x,y,label='(x,y)')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 2*np.pi)
plt.ylim(-1.5,1.5)
plt.legend()

# %%
# calculate the running average
r=5
def runningaverage(y,r):

# %%
R= runningaverage(y,5)
yra.shape
# Out:
# (89,)

# %%
#Do not modify this cell. Execution only
x = np.linspace(0,2*np.pi,100)
y = np.sin(x/2) * np.random.normal(1,0.2,size=100)
plt.scatter(x,y,label='(x,y)')
plt.plot(x[r:-r-1],R,color='red',label='Running average')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.xlim(0, 2*np.pi)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# # Problem 5
# - data is a two-dimensional numpy array. It is generated in the cell below.
# - Create a new numpy array named `newdata`, which only keeps a part of the original data array. The newdata array keeps all the elements from the original data array that are betweem the 15th entry and 25th entry (including 15th and 25th entries on axis 0, and that are between the second and the last entries of axis 1.
# - Print out the shape of this array `newdata`
# - For the new array `newdata`, calculate the ratio of its third entry on axis 0 to its 10th entry on axis 0. This ratio is an array, and print out its sum.

# %%
#Execution only. Do not modify.
np.random.seed(1)
data=np.random.random((100,5))

# %%
# your code here
